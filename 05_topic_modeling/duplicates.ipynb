# %% [markdown]
# # Identifying duplicate submissions

# %% [markdown]
# ## Setup

# %%
import os
import sys
import itertools
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity as cos_sim

# %%
# Import the dataloader
module_path = os.path.abspath(os.path.join("../04_dataset_access/"))
if module_path not in sys.path:
    sys.path.append(module_path)

# %load_ext autoreload
# %autoreload 2
import evaluation
from dataloader import Dataloader # type: ignore

# %%
# Load the dataset with document chunking
df_doc = pd.read_csv(
    "../24212003_requirements_for_artificial_intelligence/patched_feedbacks.csv"
)
df_doc = Dataloader("document", n_jobs=12, tokenize=False).from_folder(
    "../24212003_requirements_for_artificial_intelligence/attachments/", df_doc
)

# Load the dataset with page chunking
df_page = pd.read_csv(
    "../24212003_requirements_for_artificial_intelligence/patched_feedbacks.csv"
)
df_page = Dataloader("page", n_jobs=12).from_folder(
    "../24212003_requirements_for_artificial_intelligence/attachments/", df_page
)
assert len(df_page) == 2282 + 299 - 13
df_page.head(1)
# Out:
#         id                                               text language  \
# 0  2665651  Equinet welcomes the opportunity to provide co...       en
#
#   country user_type organization surname  \
# 0     BEL       ngo      Equinet     NaN
#
#                                             feedback     status company_size  \
# 0  Equinet welcomes the opportunity to provide co...  PUBLISHED        micro
#
#    ... publication publication_id publication_status tr_number  scope  \
# 0  ...   anonymous       24212003             closed       NaN    NaN
#
#   governance_level full_name      source language_detected  \
# 0              NaN       NaN  attachment                en
#
#                                            tokenized
# 0  [equinet, welcome, the, opportunity, to, provi...
#
# [1 rows x 23 columns]

# %%
# Match the internal ids of topic_modeling.ipynb
texts = pd.concat(
    (
        df_page.query("tokenized.str.len() > 0 or language_detected != 'en'"),
        df_page.query("tokenized.str.len() == 0 and language_detected == 'en'"),
    )
).reset_index(drop=True)

# Add some helpful columns
texts["page"] = texts.groupby("id").cumcount()
texts["is_feedback"] = texts["page"] == 0

# %% [markdown]
# ## Identify duplicate candidates

# %%
# Compute potential duplicates on page and document level
duplicates_page = evaluation.duplicates(texts)
duplicates_doc = evaluation.duplicates(df_doc)

# %%
from evaluation import (
    _dataset_duplicates_page_false_positives as false_positives_page,
    _dataset_duplicates_page_true_positives as true_positives_page,
)

# Filter out true positives
df = duplicates_page
df = df[~df[["id_i", "id_j"]].apply(tuple, axis=1).isin(true_positives_page)]

# Filter out false positives or irrelevant
df = df[~df[["i", "j"]].apply(tuple, axis=1).isin(false_positives_page)]

# Display some relevant columns
cols_ = ["id_i", "id_j", "similarity", "organization_i", "organization_j"]
cols = ["i", "j"] + cols_ + ["is_feedback_i", "is_feedback_j"]
df[cols].sort_values("similarity", ascending=False).head()
# Out:
#         i     j     id_i     id_j  similarity  \
# 74    436  2164  2665595  2662492    0.530941
# 161  1408  2116  2665420  2662901    0.530808
# 1      10   415  2665650  2665603    0.529833
# 85    496  1192  2665578  2665462    0.528036
# 156  1349  1719  2665431  2665231    0.527429
#
#                                      organization_i  \
# 74                                         INFOBALT
# 161       European Savings and Retail Banking Group
# 1                                        AI Austria
# 85                              Women in AI Austria
# 156  Związek Pracodawców Business & Science Poland
#
#                                  organization_j  is_feedback_i  is_feedback_j
# 74                                       Google           True          False
# 161  European Association of Co-operative Banks          False          False
# 1                             European AI Forum          False          False
# 85                            Access Now Europe          False          False
# 156                                      OpenAI           True           True

# %% [markdown]
# ## Results

# %%
# Show the duplicates or adaptations we've identified on a page-level
df = duplicates_page
df = df[df[["id_i", "id_j"]].apply(tuple, axis=1).isin(true_positives_page)]
df.sort_values("similarity", ascending=False).drop_duplicates(["id_i", "id_j"])[
    ["similarity", "organization_i", "organization_j"]
]
# Out:
#      similarity                                     organization_i  \
# 2      1.000000                                Digitalcourage e.V.
# 169    1.000000                       German Education Union (GEW)
# 185    1.000000                                              ETUCE
# 174    1.000000                       German Education Union (GEW)
# 111    0.985340                                            Beltug
# 97     0.895487                      European DIGITAL SME Alliance
# 166    0.862336                                             Biogen
# 197    0.802432  Vereinigung der Arbeitgeberverbände der Deutsc...
# 47     0.769739  European Federation of Psychologists’ Associat...
# 171    0.767765                       German Education Union (GEW)
# 184    0.767765                                              ETUCE
# 194    0.767765                                            ČMOS PŠ
# 130    0.583627                                      Volkswagen AG
# 178    0.546517                                              etami
#
#                                         organization_j
# 2                       European Digital Rights (EDRi)
# 169                                              ETUCE
# 185                                            ČMOS PŠ
# 174                                            ČMOS PŠ
# 111                             CIO Platform Nederland
# 97                      Small Business Standards (SBS)
# 166  European Federation of Pharmaceutical Industri...
# 197  BDA - Bundesvereinigung der Deutschen Arbeitge...
# 47               European Test Publishers Group (ETPG)
# 171                         Teachers' Union of Ireland
# 184                         Teachers' Union of Ireland
# 194                         Teachers' Union of Ireland
# 130                                              etami
# 178  European Automobile Manufacturers Association ...

# %%
# Filter out false positives or irrelevant
false_positives = [(60, 274), (95, 203)]
duplicates_doc = duplicates_doc[
    ~duplicates_doc[["i", "j"]].apply(tuple, axis=1).isin(false_positives)
]

# Display some relevant columns
duplicates_doc[cols_].sort_values("similarity", ascending=False)
# Out:
#       id_i     id_j  similarity  \
# 0  2665649  2665234    0.981435
# 7  2665205  2662780    0.959017
# 9  2663356  2663263    0.951901
# 2  2665574  2665497    0.906641
# 4  2665563  2665479    0.904971
# 8  2663486  2662780    0.614866
# 6  2665205  2663486    0.592789
# 1  2665586  2660588    0.502885
#
#                                       organization_i  \
# 0                                Digitalcourage e.V.
# 7                       German Education Union (GEW)
# 9  Vereinigung der Arbeitgeberverbände der Deutsc...
# 2                      European DIGITAL SME Alliance
# 4                                            Beltug
# 8                                              ETUCE
# 6                       German Education Union (GEW)
# 1                                            Philips
#
#                                       organization_j
# 0                     European Digital Rights (EDRi)
# 7                                            ČMOS PŠ
# 9  BDA - Bundesvereinigung der Deutschen Arbeitge...
# 2                     Small Business Standards (SBS)
# 4                             CIO Platform Nederland
# 8                                            ČMOS PŠ
# 6                                              ETUCE
# 1  European Coordination Committee of the Radiolo...
